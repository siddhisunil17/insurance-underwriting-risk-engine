# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

DATA_PATH = "C:\Projects\insurance-underwriting-risk-engine/data/raw/Dataset of health insurance portfolio.xlsx"
DESC_PATH = "C:\Projects\insurance-underwriting-risk-engine/data/raw/Descriptive of the varaibles.xlsx"

df = pd.read_excel(DATA_PATH)
desc = pd.read_excel(DESC_PATH)

print("Dataset shape:", df.shape)
print("Description shape:", desc.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       5
#       6 DATA_PATH = "../data/raw/Dataset of health insurance portfolio.xlsx"
#       7 DESC_PATH = "../data/raw/Descriptive of the varaibles.xlsx"
#       8
# ----> 9 df = pd.read_excel(DATA_PATH)
#      10 desc = pd.read_excel(DESC_PATH)
#      11
#      12 print("Dataset shape:", df.shape)
#
# File c:\Projects\insurance-underwriting-risk-engine\venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
# ...
